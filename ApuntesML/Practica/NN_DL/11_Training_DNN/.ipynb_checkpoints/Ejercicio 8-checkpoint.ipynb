# %% [markdown]
# # Practice training a deep neural network on the CIFAR10 image dataset:

# %% [markdown]
# ## a.
# Load CIFAR10 just like you loaded the FashionMNIST dataset in Chapter 10, but using torchvision.datasets.CIFAR10 instead of. The
# dataset is composed of 60,000 32 × 32–pixel color images (50,000 for training, 10,000 for testing) with 10 classes.

# %%
import torchvision
import torchvision.transforms.v2 as T
from torch.utils.data import DataLoader
import torchmetrics
# Out:
# Requirement already satisfied: torch in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (2.12.1)
# Requirement already satisfied: torchvision in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (0.27.1)
# Requirement already satisfied: filelock in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from torch) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from torch) (2026.6.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.2)
# Requirement already satisfied: nvidia-cublas<=13.1.1.3,>=13.1.0.3 in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from torch) (13.1.1.3)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from torch) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from torch) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from torch) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from torch) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from torch) (3.4.5)
# Requirement already satisfied: triton==3.7.1 in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from torch) (3.7.1)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.85)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from cuda-bindings<14,>=13.0.3->torch) (1.5.5)
# Requirement already satisfied: numpy in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from torchvision) (2.4.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from torchvision) (12.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/danielbb/Documentos/Proyectos/ML-Roadmap/ApuntesML/Practica/NN_DL/.venv/lib/python3.14/site-packages (from jinja2->torch) (3.0.3)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 get_ipython().system('pip install torch torchvision')
# ----> 2 import torchvision
#       3 import torchvision.transforms.v2 as T
#       4 from torch.utils.data import DataLoader
#       5 import torchmetrics
#
# ModuleNotFoundError: No module named 'torchvision'

# %%
toTensor = T.Compose([T.ToImage(), T.ToDtype(torch.float32, scale=True)])

train_and_valid_data = torchvision.datasets.CIFAR10(
root="datasets", train=True, download=True, transform=toTensor)

test_data = torchvision.datasets.CIFAR10(
root="datasets", train=False, download=True, transform=toTensor)

torch.manual_seed(42)
learning_rate = 0.002 

train_data, valid_data = torch.utils.data.random_split(
train_and_valid_data, [55_000, 5_000])
